# %% [markdown]
# <span style="color:blue; font-weight:bold; font-size:24px;">IMDB DATASET - CAPSTONE PROJECT PHASE 2</span>
#
# <span style="color:brown; font-weight:bold; font-size:20px;">By SATYA JYOTHI</span>
#
# <span style="color:brown; font-weight:bold; font-size:16px;">Batch: DS0622, DATATRAINED</span>

# %% [markdown]
# - **Make two tables and corresponding columns provided in the above CSV files in SQLite DBMS. Insert all data of each CSV file in each of the created tables. Now start querying the table(s) in the  SQL workbench / SQLite database**
#
# - **Table 1: Sno, MovieName, Director Name, Duration, genre, ratings**
#
# 1) Display all the details of movies created by directors Christopher and Matt Reeves.
#
# 2) Display all the details of movies with a duration of 140 minutes to 190 minutes.
#
# 3) Display all details of movies with ratings above 7 in ascending order.
#
# 4) Display all movie names in descending order.
#
# 5) Display movie name starts with ‘P’ and their rating is greater than 7.
#
# - **Table 2: Movie Name, stars, votes, Genre, Gross collection, popularity, Certification**
#
# 1) Display all movie names with star Arnold Schwarzenegger in ascending order.
#
# 2) Display all details of the movie with the highest number of votes.
#
# 3) Display movie names with gross collections in descending order.
#
# 4) Display the gross collection of movies with the star Arnold.
#
# 5) Display all details of movies with comedy and action genres.
#
# - **Make subquery :**
#
# 1) Display all details from both tables where movie names are the same.
#
# 2) Display all movie names, Director, ratings, and gross collection where the genre is action.
#
# 3) Display all details from both tables with the highest gross collection.
#
# 4) Display all details from both tables with the highest ratings
#
# 5) Display all details from both tables with the lowest gross collection and lowest ratings
#
# - **Now once completed with queries in the SQLite database, then make the exact query solutions by using PANDAS SQL in the data frame.  Load the CSV data in a data frame and start making solutions for all the above 15 queries using PANDAS SQL. You may use concat or merge joins per the requirements basis to make 5 join queries.**

# %% [markdown]
# ## Using SQLite3. Creating Table 1
#
# ### Table 1: Sno, MovieName, Director Name, Duration, metascore, ratings

# %%
import sqlite3
import csv

# Connect to the SQLite database
db = sqlite3.connect("IMDB.db")

# Create a cursor object to interact with the database
cur = db.cursor()

# Create a table1 in the database. Used SNo as PRIMARY_KEY as there are unique numbers in this column and 
# used Movie_Name as FOREIGN KEY to create referential integrity between Table 1 and Table 2
cur.execute('''CREATE TABLE Table1 (
                    SNo INT PRIMARY KEY,
                    Movie_Name TEXT,
                    Duration_min INT,
                    Year INT,
                    Ratings REAL,
                    Metascore INT,
                    Director1 TEXT,
                    Director2 TEXT,
                    Director3 TEXT,
                    Director4 TEXT,
                    Director5 TEXT,
                    Director6 TEXT,
                    FOREIGN KEY (Movie_Name) REFERENCES Table2(Movie_Name)
                )''')

# Read data from the CSV file and insert into the table
with open('IMDB_1.csv', 'r', encoding='utf-8') as file: # Used encoding='utf-8' as default one gave issue
    csv_reader = csv.reader(file)  # Creating csv_reader object using the csv.reader() function. csv.reader reads the file 
                                   # and allows to iterate over its rows.
    next(csv_reader)  # Skip the header row if present
    
    total_records=0
    for row in csv_reader:
        # Insert each row of data into the table
        cur.execute("INSERT INTO Table1 VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", row) # Dynamic insertion of data into 
                                                                                           # the table from csv file
        db.commit()  # Commit the changes to the database
        total_records+=1


print(total_records, "Records Inserted into Table1 from first CSV file")

# Close the database connection
db.close()
# Out:
# 1751 Records Inserted into Table1 from first CSV file

# %% [markdown]
# ## Using SQLite3. Creating Table 2
#
# ### Table 2: Movie Name, stars, votes, Genre, Gross collection, popularity, Certification

# %%
import sqlite3
import csv

# Connect to the SQLite database
db = sqlite3.connect("IMDB.db")

# Create a cursor object to interact with the database
cur = db.cursor()

# Create a Table2 in the database. Used "Movie_Name" as PRIMARY_KEY where as it is used as FOREIGN KEY in Table1.
cur.execute('''CREATE TABLE Table2 (
                    Movie_Name TEXT PRIMARY KEY,
                    Votes INT,
                    Certification TEXT,
                    Gross_Million_Dollars REAL,
                    Star1 TEXT,
                    Star2 TEXT,
                    Star3 TEXT,
                    Star4 TEXT,
                    Genre1 TEXT,
                    Genre2 TEXT,
                    Genre3 TEXT,
                    Popularity INT
                )''')

# Read data from the CSV file and insert into the table
with open('IMDB_2.csv', 'r', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  # Skip the header row if present
    
    total_records=0
    for row in csv_reader:
        # Insert each row of data into the table
        cur.execute("INSERT INTO Table2 VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", row)
        db.commit()  # Commit the changes to the database
        total_records+=1


print(total_records, "Records Inserted into Table2 from second CSV file")

# Close the database connection
db.close()
# Out:
# 1751 Records Inserted into Table2 from second CSV file

# %% [markdown]
# ## Queries on Table 1 using SQLite3:
#
# - **1)  Display all the details of movies created by directors Christopher and Matt Reeves.**
#
# - **2) Display all the details of movies with a duration of 140 minutes to 190 minutes.**
#
# - **3) Display all details of movies with ratings above 7 in ascending order.**
#
# - **4) Display all movie names in descending order.**
#
# - **5) Display movie name starts with ‘P’ and their rating is greater than 7.**

# %%
import sqlite3

# Connect to the SQLite database
db = sqlite3.connect("IMDB.db")

# Create a cursor object to interact with the database
cur = db.cursor()

# 1) Display all the details of movies created by directors Christopher and Matt Reeves.
cur.execute("""SELECT * FROM Table1 WHERE Director1 LIKE '%Christopher%' OR Director1 LIKE '%Matt Reeves%' 
            OR Director2 LIKE '%Christopher%' OR Director2 LIKE '%Matt Reeves%' 
            OR Director3 LIKE '%Christopher%' OR Director3 LIKE '%Matt Reeves%' 
            OR Director4 LIKE '%Christopher%' OR Director4 LIKE '%Matt Reeves%' 
            OR Director5 LIKE '%Christopher%' OR Director5 LIKE '%Matt Reeves%' 
            OR Director6 LIKE '%Christopher%' OR Director6 LIKE '%Matt Reeves%'""")


results = cur.fetchall()
print("Query1: Display all the details of movies created by directors Christopher and Matt Reeves")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(results)  # Determine the number of rows
max_rows = 20  # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    for row in results[:10]:
        print(row)

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    for row in results[-10:]:
        print(row)
else:
    # Print all results
    for row in results:
        print(row)
# Out:
# Query1: Display all the details of movies created by directors Christopher and Matt Reeves
# (2, 'The Dark Knight', 152, 2008, 9.0, 84, 'Christopher Nolan', '', '', '', '', '')
# (4, 'Inception', 148, 2010, 8.8, 74, 'Christopher Nolan', '', '', '', '', '')
# (22, 'The Dark Knight Rises', 164, 2012, 8.4, 78, 'Christopher Nolan', '', '', '', '', '')
# (43, 'Batman Begins', 140, 2005, 8.2, 70, 'Christopher Nolan', '', '', '', '', '')
# (131, 'The Batman', 176, 2022, 7.8, 72, 'Matt Reeves', '', '', '', '', '')
# (139, 'Dunkirk', 106, 2017, 7.8, 94, 'Christopher Nolan', '', '', '', '', '')
# (167, 'Mission: Impossible - Fallout', 147, 2018, 7.7, 86, 'Christopher McQuarrie', '', '', '', '', '')
# (172, 'The Lego Movie', 100, 2014, 7.7, 83, 'Phil Lord', 'Christopher Miller', '', '', '', '')
# (224, 'Dawn of the Planet of the Apes', 130, 2014, 7.6, 79, 'Matt Reeves', '', '', '', '', '')
# ...

# %%
# 2) Display all the details of movies with a duration of 140 minutes to 190 minutes.
cur.execute("SELECT * FROM Table1 WHERE Duration_min BETWEEN 140 AND 190")
results = cur.fetchall()
print("Query2: Display all the details of movies with a duration of 140 minutes to 190 minutes")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(results)  # Determine the number of rows
max_rows = 20  # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    for row in results[:10]:
        print(row)

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    for row in results[-10:]:
        print(row)
else:
    # Print all results
    for row in results:
        print(row)
# Out:
# Query2: Display all the details of movies with a duration of 140 minutes to 190 minutes
# (1, 'Spider-Man: Across the Spider-Verse', 140, 2023, 9.1, 86, 'Joaquim Dos Santos', 'Kemp Powers', 'Justin K. Thompson', '', '', '')
# (2, 'The Dark Knight', 152, 2008, 9.0, 84, 'Christopher Nolan', '', '', '', '', '')
# (4, 'Inception', 148, 2010, 8.8, 74, 'Christopher Nolan', '', '', '', '', '')
# (5, 'The Lord of the Rings: The Fellowship of the Ring', 178, 2001, 8.8, 92, 'Peter Jackson', '', '', '', '', '')
# (6, 'The Lord of the Rings: The Two Towers', 179, 2002, 8.8, 87, 'Peter Jackson', '', '', '', '', '')
# (9, 'Soorarai Pottru', 153, 2020, 8.7, '', 'Sudha Kongara', '', '', '', '', '')
# (14, 'Sita Ramam', 163, 2022, 8.6, '', 'Hanu Raghavapudi', '', '', '', '', '')
# (16, 'Gladiator', 155, 2000, 8.5, 67, 'Ridley Scott', '', '', '', '', '')
# (18, 'Avengers: Endgame', 181, 2019, 8.4, 78, 'Anthony Russo', 'Joe Russo', '', '', '', '')
# ...

# %%
# 3) Display all details of movies with ratings above 7 in ascending order.
cur.execute("SELECT * FROM Table1 WHERE Ratings > 7 ORDER BY Ratings ASC")
results = cur.fetchall()
print("Query3: Display all details of movies with ratings above 7 in ascending order")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(results)  # Determine the number of rows
max_rows = 20  # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    for row in results[:10]:
        print(row)

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    for row in results[-10:]:
        print(row)
else:
    # Print all results
    for row in results:
        print(row)
# Out:
# Query3: Display all details of movies with ratings above 7 in ascending order
# (431, 'Furious 7', 137, 2015, 7.1, 67, 'James Wan', '', '', '', '', '')
# (432, 'The Mummy (1999)', 124, 1999, 7.1, 48, 'Stephen Sommers', '', '', '', '', '')
# (433, 'Mission: Impossible', 110, 1996, 7.1, 59, 'Brian De Palma', '', '', '', '', '')
# (434, 'Free Guy', 115, 2021, 7.1, 62, 'Shawn Levy', '', '', '', '', '')
# (435, 'Wrath of Man', 119, 2021, 7.1, 57, 'Guy Ritchie', '', '', '', '', '')
# (436, 'Tropic Thunder', 107, 2008, 7.1, 71, 'Ben Stiller', '', '', '', '', '')
# (437, 'Prey', 100, 2022, 7.1, 71, 'Dan Trachtenberg', '', '', '', '', '')
# (438, 'Man of Steel', 143, 2013, 7.1, 55, 'Zack Snyder', '', '', '', '', '')
# (439, 'Everest', 121, 2015, 7.1, 64, 'Baltasar Kormákur', '', '', '', '', '')
# (440, 'Blade', 120, 1998, 7.1, 47, 'Stephen Norrington', '', '', '', '', '')
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# 4) Display all movie names in descending order.
cur.execute("SELECT Movie_Name FROM Table1 ORDER BY Movie_Name DESC")
results = cur.fetchall()
print("Query4: Display all movie names in descending order")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(results)  # Determine the number of rows
max_rows = 20  # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    for row in results[:10]:
        print(row)

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    for row in results[-10:]:
        print(row)
else:
    # Print all results
    for row in results:
        print(row)
# Out:
# Query4: Display all movie names in descending order
# ('Æon Flux',)
# ('xXx: State of the Union',)
# ('xXx: Return of Xander Cage',)
# ('xXx',)
# ('Zoolander 2',)
# ('Zombieland: Double Tap',)
# ('Zombieland',)
# ('Zathura: A Space Adventure',)
# ("Zack Snyder's Justice League",)
# ('Your Highness',)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ('1917',)
# ('16 Blocks',)
# ('15 Minutes',)
# ('13 Hours',)
# ('13 Assassins',)
# ('12 Strong',)
# ('12 Rounds',)
# ('10,000 BC',)
# ("'71",)
# ('#Alive',)

# %%
# 5) Display movie name starts with ‘P’ and their rating is greater than 7.
cur.execute("SELECT Movie_Name FROM Table1 WHERE Movie_Name LIKE 'P%' AND Ratings > 7")
results = cur.fetchall()
print("Query5: Display movie name starts with ‘P’ and their rating is greater than 7")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(results)  # Determine the number of rows
max_rows = 20  # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    for row in results[:10]:
        print(row)

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    for row in results[-10:]:
        print(row)
else:
    # Print all results
    for row in results:
        print(row)

# Close the cursor and the database connection
cur.close()
db.close()
# Out:
# Query5: Display movie name starts with ‘P’ and their rating is greater than 7
# ('Princess Mononoke',)
# ('Paan Singh Tomar',)
# ('Pirates of the Caribbean: The Curse of the Black Pearl',)
# ('Predator',)
# ('Ponniyin Selvan: Part I',)
# ('Pushpa: The Rise - Part 1',)
# ('Police Story',)
# ('Predestination',)
# ("Pirates of the Caribbean: Dead Man's Chest",)
# ('Patriots Day',)
# ('Point Break (1991)',)
# ('Prey',)
# ("Pirates of the Caribbean: At World's End",)
# ('Planet Terror',)
# ('Payback',)

# %% [markdown]
# ## Queries on Table 2 using SQLite3:
#
# - **1) Display all movie names with star Arnold Schwarzenegger in ascending order.**
#
# - **2) Display all details of the movie with the highest number of votes.**
#
# - **3) Display movie names with gross collections in descending order.**
#
# - **4) Display the gross collection of movies with the star Arnold.**
#
# - **5) Display all details of movies with comedy and action genres.**

# %%
import sqlite3

# Connect to the SQLite database
db = sqlite3.connect("IMDB.db")

# Create a cursor object to interact with the database
cur = db.cursor()

# 1) Display all movie names with star Arnold Schwarzenegger in ascending order.
cur.execute("""SELECT Movie_Name FROM Table2 WHERE Star1 = 'Arnold Schwarzenegger' OR Star2 = 'Arnold Schwarzenegger' 
            OR Star3 = 'Arnold Schwarzenegger' OR Star4 = 'Arnold Schwarzenegger' ORDER BY Movie_Name ASC""")
results = cur.fetchall()
print("Query1: Display all movie names with star Arnold Schwarzenegger in ascending order")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(results)  # Determine the number of rows
max_rows = 20  # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    for row in results[:10]:
        print(row)

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    for row in results[-10:]:
        print(row)
else:
    # Print all results
    for row in results:
        print(row)
# Out:
# Query1: Display all movie names with star Arnold Schwarzenegger in ascending order
# ('Batman & Robin',)
# ('Collateral Damage',)
# ('Commando',)
# ('Conan the Barbarian (1982)',)
# ('Conan the Destroyer',)
# ('End of Days',)
# ('Eraser',)
# ('Escape Plan',)
# ('Kindergarten Cop',)
# ('Last Action Hero',)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ('Terminator 2: Judgment Day',)
# ('Terminator 3: Rise of the Machines',)
# ('Terminator Genisys',)
# ('Terminator: Dark Fate',)
# ('The 6th Day',)
# ('The Last Stand',)
# ('The Running Man',)
# ('The Terminator',)
# ('Total Recall (1990)',)
# ('True Lies',)

# %%
# 2) Display all details of the movie with the highest number of votes.
cur.execute("SELECT * FROM Table2 WHERE Votes = (SELECT MAX(Votes) FROM Table2 WHERE Votes <> '') ")
results = cur.fetchall()
print("Query2: Display all details of the movie with the highest number of votes")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(results)  # Determine the number of rows
max_rows = 20  # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    for row in results[:10]:
        print(row)

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    for row in results[-10:]:
        print(row)
else:
    # Print all results
    for row in results:
        print(row)
# Out:
# Query2: Display all details of the movie with the highest number of votes
# ('The Dark Knight', 2719626, 'PG-13', 534.86, 'Christian Bale', 'Heath Ledger', 'Aaron Eckhart', 'Michael Caine', 'Action', ' Crime', ' Drama', 117)

# %%
# 3) Display movie names with gross collections in descending order.
cur.execute("SELECT Movie_Name FROM Table2 WHERE Gross_Million_Dollars <> '' ORDER BY Gross_Million_Dollars DESC")
results = cur.fetchall()
print("Query3: Display movie names with gross collections in descending order")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(results)  # Determine the number of rows
max_rows = 20  # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    for row in results[:10]:
        print(row)

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    for row in results[-10:]:
        print(row)
else:
    # Print all results
    for row in results:
        print(row)
# Out:
# Query3: Display movie names with gross collections in descending order
# ('Star Wars: Episode VII - The Force Awakens',)
# ('Avengers: Endgame',)
# ('Spider-Man: No Way Home',)
# ('Avatar',)
# ('Top Gun: Maverick',)
# ('Black Panther',)
# ('Avengers: Infinity War',)
# ('Avatar: The Way of Water',)
# ('Jurassic World',)
# ('The Avengers (2012)',)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ('The Man from Nowhere',)
# ('The Salvation',)
# ('Charlie Countryman',)
# ('Rogue',)
# ('Welcome to the Punch',)
# ('Mutant Chronicles',)
# ("Knockin' on Heaven's Door",)
# ('Son of a Gun',)
# ('The Condemned',)
# ('Wild Card',)

# %%
# 4) Display the gross collection of movies with the star Arnold.
cur.execute("""SELECT Movie_Name, Gross_Million_Dollars FROM Table2 WHERE Star1 LIKE '%Arnold%' OR Star2 LIKE '%Arnold%' 
            OR Star3 LIKE '%Arnold%' OR Star4 LIKE '%Arnold%'""")
results = cur.fetchall()
print("Query4: Display the gross collection of movies with the star Arnold")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(results)  # Determine the number of rows
max_rows = 20  # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    for row in results[:10]:
        print(row)

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    for row in results[-10:]:
        print(row)
else:
    # Print all results
    for row in results:
        print(row)
# Out:
# Query4: Display the gross collection of movies with the star Arnold
# ('Terminator 2: Judgment Day', 204.84)
# ('The Terminator', 38.4)
# ('Predator', 59.74)
# ('Total Recall (1990)', 119.39)
# ('True Lies', 146.28)
# ('The Mummy (1999)', 155.25)
# ('Conan the Barbarian (1982)', 39.57)
# ('The Running Man', 38.12)
# ('Commando', 35.1)
# ('Escape Plan', 25.13)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ('Eraser', 101.3)
# ('Red Heat', 34.99)
# ('Conan the Destroyer', 31.04)
# ('The 6th Day', 34.6)
# ('End of Days', 66.89)
# ('Sabotage', 10.51)
# ('Raw Deal', 16.21)
# ('Collateral Damage', 40.08)
# ('Red Sonja', 6.95)
# ('Batman & Robin', 107.33)

# %%
# 5) Display all details of movies with comedy and action genres.
query = """
    SELECT *
    FROM Table2
    WHERE
        (Genre1 LIKE '%Comedy%' OR Genre2 LIKE '%Comedy%' OR Genre3 LIKE '%Comedy%')
        AND (Genre1 LIKE '%Action%' OR Genre2 LIKE '%Action%' OR Genre3 LIKE '%Action%')
"""

# Execute the query and fetch the results
cur.execute(query)
results = cur.fetchall()

# Print the details of the movies
print("Query5: Display all details of movies with comedy and action genres")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(results)  # Determine the number of rows
max_rows = 20  # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    for row in results[:10]:
        print(row)

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    for row in results[-10:]:
        print(row)
else:
    # Print all results
    for row in results:
        print(row)
    
# Close the database connection
db.close()
# Out:
# Query5: Display all details of movies with comedy and action genres
# ('Guardians of the Galaxy Vol. 3', 155369, 'PG-13', '', 'Chris Pratt', 'Chukwudi Iwuji', 'Bradley Cooper', 'Pom Klementieff', 'Action', ' Adventure', ' Comedy', 3)
# ('Gangs of Wasseypur', 99386, 'Not Rated', '', 'Manoj Bajpayee', 'Nawazuddin Siddiqui', 'Tigmanshu Dhulia', 'Richa Chadha', 'Action', ' Comedy', ' Crime', 4011)
# ('Sherlock Jr.', 52480, 'Passed', 0.98, 'Buster Keaton', 'Kathryn McGuire', 'Joe Keaton', 'Erwin Connelly', 'Action', ' Comedy', ' Romance', '')
# ('Lock, Stock and Two Smoking Barrels', 595448, 'R', 3.9, 'Jason Flemyng', 'Dexter Fletcher', 'Nick Moran', 'Jason Statham', 'Action', ' Comedy', ' Crime', 894)
# ('Sholay', 57088, 'Not Rated', '', 'Sanjeev Kumar', 'Dharmendra', 'Amitabh Bachchan', 'Amjad Khan', 'Action', ' Adventure', ' Comedy', '')
# ...

# %% [markdown]
# ## Make subquery using SQLite3:
#
# - **1) Display all details from both tables where movie names are the same.**
#
# - **2) Display all movie names, Director, ratings, and gross collection where the genre is action.**
#
# - **3) Display all details from both tables with the highest gross collection.**
#
# - **4) Display all details from both tables with the highest ratings**
#
# - **5) Display all details from both tables with the lowest gross collection and lowest ratings**

# %%
import sqlite3

# dbect to the SQLite database
db = sqlite3.connect('IMDB.db')
cur = db.cursor()

# Subquery: Display all details from both tables where movie names are the same
subquery1 = """
    SELECT *
    FROM Table1
    INNER JOIN Table2 ON Table1.Movie_Name = Table2.Movie_Name
"""
cur.execute(subquery1)
results1 = cur.fetchall()
print("Subquery1: Display all details from both tables where movie names are the same")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(results1)  # Determine the number of rows
max_rows = 20  # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    for row in results1[:10]:
        print(row)

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    for row in results1[-10:]:
        print(row)
else:
    # Print all results
    for row in results1:
        print(row)
# Out:
# Subquery1: Display all details from both tables where movie names are the same
# (1, 'Spider-Man: Across the Spider-Verse', 140, 2023, 9.1, 86, 'Joaquim Dos Santos', 'Kemp Powers', 'Justin K. Thompson', '', '', '', 'Spider-Man: Across the Spider-Verse', 38365, 'PG', '', 'Shameik Moore', 'Hailee Steinfeld', 'Oscar Isaac', 'Luna Lauren Velez', 'Animation', ' Action', ' Adventure', 23)
# (2, 'The Dark Knight', 152, 2008, 9.0, 84, 'Christopher Nolan', '', '', '', '', '', 'The Dark Knight', 2719626, 'PG-13', 534.86, 'Christian Bale', 'Heath Ledger', 'Aaron Eckhart', 'Michael Caine', 'Action', ' Crime', ' Drama', 117)
# (3, 'The Lord of the Rings: The Return of the King', 201, 2003, 9.0, 94, 'Peter Jackson', '', '', '', '', '', 'The Lord of the Rings: The Return of the King', 1887925, 'PG-13', 377.85, 'Elijah Wood', 'Viggo Mortensen', 'Ian McKellen', 'Orlando Bloom', 'Action', ' Adventure', ' Drama', 407)
# ...

# %%
# Query: Display all movie names, Director, ratings, and gross collection where the genre is action
query2 = """
    SELECT Table2.Movie_Name, Table1.Director1, Table1.Director2, Table1.Director3, Table1.Director4, 
    Table1.Director5, Table1.Director6,  Table1.Ratings, Table2.Gross_Million_Dollars
    FROM Table1
    INNER JOIN Table2 ON Table1.Movie_Name = Table2.Movie_Name
    WHERE Table2.Genre1 = 'Action' OR Table2.Genre2 = 'Action' OR Table2.Genre3 = 'Action'
"""
cur.execute(query2)
results2 = cur.fetchall()
print("Subquery2: Display all movie names, Director, ratings, and gross collection where the genre is action")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(results2)  # Determine the number of rows
max_rows = 20  # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    for row in results2[:10]:
        print(row)

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    for row in results2[-10:]:
        print(row)
else:
    # Print all results
    for row in results2:
        print(row)
# Out:
# Subquery2: Display all movie names, Director, ratings, and gross collection where the genre is action
# ('The Dark Knight', 'Christopher Nolan', '', '', '', '', '', 9.0, 534.86)
# ('The Lord of the Rings: The Return of the King', 'Peter Jackson', '', '', '', '', '', 9.0, 377.85)
# ('Inception', 'Christopher Nolan', '', '', '', '', '', 8.8, 292.58)
# ('The Lord of the Rings: The Fellowship of the Ring', 'Peter Jackson', '', '', '', '', '', 8.8, 315.54)
# ('The Lord of the Rings: The Two Towers', 'Peter Jackson', '', '', '', '', '', 8.8, 342.55)
# ('The Matrix', 'Lana Wachowski', 'Lilly Wachowski', '', '', '', '', 8.7, 171.48)
# ('Star Wars: Episode V - The Empire Strikes Back', 'Irvin Kershner', '', '', '', '', '', 8.7, 290.48)
# ('Soorarai Pottru', 'Sudha Kongara', '', '', '', '', '', 8.7, '')
# ('Star Wars: Episode IV - A New Hope', 'George Lucas', '', '', '', '', '', 8.6, 322.74)
# ('Terminator 2: Judgment Day', 'James Cameron', '', '', '', '', '', 8.6, 204.84)
# ...

# %%
# Query: Display all details from both tables with the highest gross collection
query3 = """
    SELECT *
    FROM Table1
    INNER JOIN Table2 ON Table1.Movie_Name = Table2.Movie_Name
    WHERE Table2.Gross_Million_Dollars = (
        SELECT MAX(Gross_Million_Dollars) FROM Table2 WHERE Gross_Million_Dollars <> ''
    )
"""
cur.execute(query3)
results3 = cur.fetchall()
print("Subquery3: Display all details from both tables with the highest gross collection")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(results3)  # Determine the number of rows
max_rows = 20  # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    for row in results3[:10]:
        print(row)

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    for row in results3[-10:]:
        print(row)
else:
    # Print all results
    for row in results3:
        print(row)
# Out:
# Subquery3: Display all details from both tables with the highest gross collection
# (137, 'Star Wars: Episode VII - The Force Awakens', 138, 2015, 7.8, 80, 'J.J. Abrams', '', '', '', '', '', 'Star Wars: Episode VII - The Force Awakens', 947641, 'PG-13', 936.66, 'Daisy Ridley', 'John Boyega', 'Oscar Isaac', 'Domhnall Gleeson', 'Action', ' Adventure', ' Sci-Fi', 455)

# %%
# Query: Display all details from both tables with the highest ratings
query4 = """
    SELECT *
    FROM Table1
    INNER JOIN Table2 ON Table1.Movie_Name = Table2.Movie_Name
    WHERE Table1.Ratings = (
        SELECT MAX(Ratings) FROM Table1 WHERE Ratings <> ''
    )
"""
cur.execute(query4)
results4 = cur.fetchall()
print("Subquery4: Display all details from both tables with the highest ratings")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(results4)  # Determine the number of rows
max_rows = 20  # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    for row in results4[:10]:
        print(row)

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    for row in results4[-10:]:
        print(row)
else:
    # Print all results
    for row in results4:
        print(row)
# Out:
# Subquery4: Display all details from both tables with the highest ratings
# (1, 'Spider-Man: Across the Spider-Verse', 140, 2023, 9.1, 86, 'Joaquim Dos Santos', 'Kemp Powers', 'Justin K. Thompson', '', '', '', 'Spider-Man: Across the Spider-Verse', 38365, 'PG', '', 'Shameik Moore', 'Hailee Steinfeld', 'Oscar Isaac', 'Luna Lauren Velez', 'Animation', ' Action', ' Adventure', 23)

# %%
# Query: Display all details from both tables with the lowest gross collection and lowest ratings

query5 = """
    SELECT *
    FROM Table1
    INNER JOIN Table2 ON Table1.Movie_Name = Table2.Movie_Name
    ORDER BY Table2.Gross_Million_Dollars ASC, Table1.Ratings ASC
    LIMIT 1
"""
cur.execute(query5)
results5 = cur.fetchall()
print("Subquery5: Display all details from both tables with the lowest gross collection and lowest ratings")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(results5)  # Determine the number of rows
max_rows = 20  # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    for row in results5[:10]:
        print(row)

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    for row in results5[-10:]:
        print(row)
else:
    # Print all results
    for row in results5:
        print(row)

# Close the database dbection
db.close()
# Out:
# Subquery5: Display all details from both tables with the lowest gross collection and lowest ratings
# (1483, 'Wild Card', 92, 2015, 5.6, 40, 'Simon West', '', '', '', '', '', 'Wild Card', 57783, 'R', 0.0, 'Jason Statham', 'Michael Angarano', 'Dominik Garcia', 'Milo Ventimiglia', 'Action', ' Crime', ' Drama', 3208)

# %% [markdown]
# - **Now once completed with queries in the SQLite database, then make the exact query solutions by using PANDAS SQL in the data frame.  Load the CSV data in a data frame and start making solutions for all the above 15 queries using PANDAS SQL. You may use concat or merge joins per the requirements basis to make 5 join queries.**

# %% [markdown]
# ## Using PANDAS
#
# ### Dataframe 1: Sno, MovieName, Director Name, Duration, metascore, ratings

# %%
# importing required initial libraries
import numpy as np                 # Basic computation library
import pandas as pd                # for data wrangling purpose

import warnings
warnings.filterwarnings("ignore")  # Filtering warnings

# %%
# Reading csv file1
df_1=pd.read_csv("IMDB_1.csv", encoding='utf-8')
pd.set_option('display.max_columns', None)
df_1
# Out:
#       SNo.                                         Movie Name  Duration (min)  \
# 0        1                Spider-Man: Across the Spider-Verse             140
# 1        2                                    The Dark Knight             152
# 2        3      The Lord of the Rings: The Return of the King             201
# 3        4                                          Inception             148
# 4        5  The Lord of the Rings: The Fellowship of the Ring             178
# ...    ...                                                ...             ...
# 1746  1747                                              Radhe             109
# 1747  1748                                             Race 3             160
# 1748  1749                                  Angels Apocalypse              85
# 1749  1750                              The Cost of Deception             125
# 1750  1751                                            Sadak 2             133
#
# ...

# %% [markdown]
# ## Using PANDAS
#
# ### Dataframe 2: Movie Name, stars, votes, Genre, Gross collection, popularity, Certification

# %%
# Reading csv file
df_2=pd.read_csv("IMDB_2.csv", encoding='utf-8')
df_2
# Out:
#                                              Movie Name    Votes  \
# 0                   Spider-Man: Across the Spider-Verse    38365
# 1                                       The Dark Knight  2719626
# 2         The Lord of the Rings: The Return of the King  1887925
# 3                                             Inception  2414206
# 4     The Lord of the Rings: The Fellowship of the Ring  1916545
# ...                                                 ...      ...
# 1746                                              Radhe   178812
# 1747                                             Race 3    47590
# 1748                                  Angels Apocalypse    42911
# 1749                              The Cost of Deception    39491
# 1750                                            Sadak 2    96260
#
#      Certification  Gross (USD millions)             Star 1  \
# 0               PG                   NaN      Shameik Moore
# 1            PG-13                534.86     Christian Bale
# ...

# %% [markdown]
# ## Queries on Dataframe 1 using PANDAS:
#
# - **1)  Display all the details of movies created by directors Christopher and Matt Reeves.**
#
# - **2) Display all the details of movies with a duration of 140 minutes to 190 minutes.**
#
# - **3) Display all details of movies with ratings above 7 in ascending order.**
#
# - **4) Display all movie names in descending order.**
#
# - **5) Display movie name starts with ‘P’ and their rating is greater than 7.**

# %%
# 1) Display all the details of movies created by directors where 'Christopher' or 'Matt Reeves' is part of any director name.
query1 = df_1[df_1['Director 1'].str.contains('Christopher|Matt Reeves') |
              df_1['Director 2'].str.contains('Christopher|Matt Reeves') |
              df_1['Director 3'].str.contains('Christopher|Matt Reeves') |
              df_1['Director 4'].str.contains('Christopher|Matt Reeves') |
              df_1['Director 5'].str.contains('Christopher|Matt Reeves') |
              df_1['Director 6'].str.contains('Christopher|Matt Reeves') ]

print("Query1: Display all the details of movies created by directors Christopher and Matt Reeves")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(query1) # Determine the number of rows
max_rows = 20 # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    display(query1.head(10))

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    display(query1.tail(10))
else:
    # Print all rows
    display(query1)
# Out:
# Query1: Display all the details of movies created by directors Christopher and Matt Reeves
#      SNo.                          Movie Name  Duration (min)  Year  Ratings  \
# 1       2                     The Dark Knight             152  2008      9.0
# 3       4                           Inception             148  2010      8.8
# 21     22               The Dark Knight Rises             164  2012      8.4
# 42     43                       Batman Begins             140  2005      8.2
# 130   131                          The Batman             176  2022      7.8
# 138   139                             Dunkirk             106  2017      7.8
# 166   167       Mission: Impossible - Fallout             147  2018      7.7
# 171   172                      The Lego Movie             100  2014      7.7
# 223   224      Dawn of the Planet of the Apes             130  2014      7.6
# 292   293  Mission: Impossible - Rogue Nation             131  2015      7.4
#
# ...

# %%
# 2) Display all the details of movies with a duration of 140 minutes to 190 minutes.
query2 = df_1[(df_1['Duration (min)'] >= 140) & (df_1['Duration (min)'] <= 190)]
print("Query2: Display all the details of movies with a duration of 140 minutes to 190 minutes")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(query2) # Determine the number of rows
max_rows = 20 # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    display(query2.head(10))

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    display(query2.tail(10))
else:
    # Print all rows
    display(query2)
# Out:
# Query2: Display all the details of movies with a duration of 140 minutes to 190 minutes
#     SNo.                                         Movie Name  Duration (min)  \
# 0      1                Spider-Man: Across the Spider-Verse             140
# 1      2                                    The Dark Knight             152
# 3      4                                          Inception             148
# 4      5  The Lord of the Rings: The Fellowship of the Ring             178
# 5      6              The Lord of the Rings: The Two Towers             179
# 8      9                                    Soorarai Pottru             153
# 13    14                                         Sita Ramam             163
# 15    16                                          Gladiator             155
# 17    18                                  Avengers: Endgame             181
# 19    20                             Avengers: Infinity War             149
#
# ...

# %%
# 3) Display all details of movies with ratings above 7 in ascending order.
query3 = df_1[df_1['Ratings'] > 7].sort_values('Ratings')
print("Query3: Display all details of movies with ratings above 7 in ascending order")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(query3) # Determine the number of rows
max_rows = 20 # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    display(query3.head(10))

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    display(query3.tail(10))
else:
    # Print all rows
    display(query3)
# Out:
# Query3: Display all details of movies with ratings above 7 in ascending order
#      SNo.                                Movie Name  Duration (min)  Year  \
# 487   488                            Gabbar Is Back             128  2015
# 455   456                     Live Free or Die Hard             128  2007
# 454   455                          We Were Soldiers             138  2002
# 453   454                      Escape from New York              99  1981
# 452   453                                  I, Robot             115  2004
# 451   452                                 Desperado             104  1995
# 450   451                   DC League of Super-Pets             105  2022
# 449   450                                  Creed II             130  2018
# 448   449                             American Made             115  2017
# 447   448  Pirates of the Caribbean: At World's End             169  2007
#
# ...

# %%
# 4) Display all movie names in descending order.
query4 = df_1.sort_values('Movie Name', ascending=False)[['Movie Name']]
print("Query4: Display all movie names in descending order")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(query4) # Determine the number of rows
max_rows = 20 # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    display(query4.head(10))

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    display(query4.tail(10))
else:
    # Print all rows
    display(query4)
# Out:
# Query4: Display all movie names in descending order
#                         Movie Name
# 1564                      Æon Flux
# 1697       xXx: State of the Union
# 1613    xXx: Return of Xander Cage
# 1368                           xXx
# 1677                   Zoolander 2
# 694         Zombieland: Double Tap
# 218                     Zombieland
# 1109    Zathura: A Space Adventure
# 109   Zack Snyder's Justice League
# 1519                 Your Highness
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#         Movie Name
# 40            1917
# 826      16 Blocks
# 1236    15 Minutes
# 336       13 Hours
# 272   13 Assassins
# 856      12 Strong
# 1508     12 Rounds
# 1638     10,000 BC
# 421            '71
# 1043        #Alive

# %%
# 5) Display movie names that start with 'P' and their rating is greater than 7.
query5 = df_1['Movie Name'][(df_1['Movie Name'].str.startswith('P')) & (df_1['Ratings'] > 7)]
print("Query5: Display movie name starts with ‘P’ and their rating is greater than 7")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(query5) # Determine the number of rows
max_rows = 20 # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    display(query5.head(10))

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    display(query5.tail(10))
else:
    # Print all rows
    display(query5)
# Out:
# Query5: Display movie name starts with ‘P’ and their rating is greater than 7
# 28                                     Princess Mononoke
# 56                                      Paan Singh Tomar
# 59     Pirates of the Caribbean: The Curse of the Bla...
# 140                                             Predator
# 190                              Ponniyin Selvan: Part I
# 238                            Pushpa: The Rise - Part 1
# 270                                         Police Story
# 300                                       Predestination
# 341           Pirates of the Caribbean: Dead Man's Chest
# 345                                         Patriots Day
# 378                                   Point Break (1991)
# 436                                                 Prey
# 447             Pirates of the Caribbean: At World's End
# 459                                        Planet Terror
# 469                                              Payback
# Name: Movie Name, dtype: object

# %% [markdown]
# ## Queries on Dataframe 2 using PANDAS:
#
# - **1) Display all movie names with star Arnold Schwarzenegger in ascending order.**
#
# - **2) Display all details of the movie with the highest number of votes.**
#
# - **3) Display movie names with gross collections in descending order.**
#
# - **4) Display the gross collection of movies with the star Arnold.**
#
# - **5) Display all details of movies with comedy and action genres.**

# %%
# 1) Display all movie names with star Arnold Schwarzenegger in ascending order.
query1 = df_2[df_2[['Star 1', 'Star 2', 'Star 3', 'Star 4']].apply(lambda x: 'Arnold Schwarzenegger' in x.values, axis=1)]
query1 = query1.sort_values('Movie Name', ascending=True)[['Movie Name']]
print("Query1: Display all movie names with star Arnold Schwarzenegger in ascending order")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(query1) # Determine the number of rows
max_rows = 20 # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    display(query1.head(10))

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    display(query1.tail(10))
else:
    # Print all rows
    display(query1)
# Out:
# Query1: Display all movie names with star Arnold Schwarzenegger in ascending order
#                       Movie Name
# 1725              Batman & Robin
# 1537           Collateral Damage
# 683                     Commando
# 560   Conan the Barbarian (1982)
# 1312         Conan the Destroyer
# 1380                 End of Days
# 1138                      Eraser
# 699                  Escape Plan
# 1070            Kindergarten Cop
# 913             Last Action Hero
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#                               Movie Name
# 10            Terminator 2: Judgment Day
# 1008  Terminator 3: Rise of the Machines
# 1002                  Terminator Genisys
# 1071               Terminator: Dark Fate
# 1337                         The 6th Day
# 1004                      The Last Stand
# ...

# %%
# 2) Display all details of the movie with the highest number of votes.
query2 = df_2[df_2['Votes']==df_2['Votes'].max()]
print("Query2: Display all details of the movie with the highest number of votes")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(query2) # Determine the number of rows
max_rows = 20 # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    display(query2.head(10))

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    display(query2.tail(10))
else:
    # Print all rows
    display(query2)
# Out:
# Query2: Display all details of the movie with the highest number of votes
#         Movie Name    Votes Certification  Gross (USD millions)  \
# 1  The Dark Knight  2719626         PG-13                534.86
#
#            Star 1        Star 2         Star 3         Star 4  Genre1  Genre2  \
# 1  Christian Bale  Heath Ledger  Aaron Eckhart  Michael Caine  Action   Crime
#
#    Genre3  Popularity
# 1   Drama       117.0

# %%
# 3) Display movie names with gross collections in descending order.
query3 = df_2[df_2['Gross (USD millions)'].notnull()].sort_values('Gross (USD millions)', ascending=False)[['Movie Name']]
print("Query3: Display movie names with gross collections in descending order")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(query3) # Determine the number of rows
max_rows = 20 # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    display(query3.head(10))

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    display(query3.tail(10))
else:
    # Print all rows
    display(query3)
# Out:
# Query3: Display movie names with gross collections in descending order
#                                      Movie Name
# 136  Star Wars: Episode VII - The Force Awakens
# 17                            Avengers: Endgame
# 37                      Spider-Man: No Way Home
# 107                                      Avatar
# 25                            Top Gun: Maverick
# 330                               Black Panther
# 19                       Avengers: Infinity War
# 163                    Avatar: The Way of Water
# 571                              Jurassic World
# 85                          The Avengers (2012)
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#                      Movie Name
# 1065         Charlie Countryman
# 729               The Salvation
# 1126                      Rogue
# 1630          Mutant Chronicles
# ...

# %%
# 4) Display the gross collection of movies with the star Arnold.

query4 = df_2[df_2[['Star 1', 'Star 2', 'Star 3', 'Star 4']].apply(lambda x: x.str.contains('Arnold').any(), axis=1)] \
[['Movie Name', 'Gross (USD millions)']]

print("Query4: Display the gross collection of movies with the star Arnold")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(query4) # Determine the number of rows
max_rows = 20 # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    display(query4.head(10))

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    display(query4.tail(10))
else:
    # Print all rows
    display(query4)
# Out:
# Query4: Display the gross collection of movies with the star Arnold
#                      Movie Name  Gross (USD millions)
# 10   Terminator 2: Judgment Day                204.84
# 61               The Terminator                 38.40
# 140                    Predator                 59.74
# 256         Total Recall (1990)                119.39
# 325                   True Lies                146.28
# 431            The Mummy (1999)                155.25
# 560  Conan the Barbarian (1982)                 39.57
# 674             The Running Man                 38.12
# 683                    Commando                 35.10
# 699                 Escape Plan                 25.13
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#                Movie Name  Gross (USD millions)
# 1138               Eraser                101.30
# ...

# %%
# 5) Display all details of movies with comedy and action genres.
query5 = df_2[(df_2['Genre1'].str.contains('Comedy')) | (df_2['Genre2'].str.contains('Comedy')) \
              | (df_2['Genre3'].str.contains('Comedy'))]
query5 = query5[(query5['Genre1'].str.contains('Action')) | (query5['Genre2'].str.contains('Action')) \
                | (query5['Genre3'].str.contains('Action'))]

print("Query5: Display all details of movies with comedy and action genres")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(query5) # Determine the number of rows
max_rows = 20 # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    display(query5.head(10))

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    display(query5.tail(10))
else:
    # Print all rows
    display(query5)
# Out:
# Query5: Display all details of movies with comedy and action genres
#                              Movie Name    Votes Certification  \
# 36       Guardians of the Galaxy Vol. 3   155369         PG-13
# 47                   Gangs of Wasseypur    99386     Not Rated
# 53                         Sherlock Jr.    52480        Passed
# 63  Lock, Stock and Two Smoking Barrels   595448             R
# 69                               Sholay    57088     Not Rated
# 70                    Bajrangi Bhaijaan    91967     Not Rated
# 71                          The General    93911        Passed
# 77                           Hera Pheri    69442     Not Rated
# 81              Guardians of the Galaxy  1219272         PG-13
# 84                             Deadpool  1068430             R
#
#     Gross (USD millions)          Star 1               Star 2  \
# 36                   NaN     Chris Pratt       Chukwudi Iwuji
# 47                   NaN  Manoj Bajpayee  Nawazuddin Siddiqui
# ...

# %% [markdown]
# ## Make subquery using PANDAS:
#
# - **1) Display all details from both tables where movie names are the same.**
#
# - **2) Display all movie names, Director, ratings, and gross collection where the genre is action.**
#
# - **3) Display all details from both tables with the highest gross collection.**
#
# - **4) Display all details from both tables with the highest ratings**
#
# - **5) Display all details from both tables with the lowest gross collection and lowest ratings**

# %%
# 1) Display all details from both tables where movie names are the same.
query1 = pd.merge(df_1, df_2, on='Movie Name', how='inner')
print("Subquery1: Display all details from both tables where movie names are the same")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(query1) # Determine the number of rows
max_rows = 20 # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    display(query1.head(10))

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    display(query1.tail(10))
else:
    # Print all rows
    display(query1)
# Out:
# Subquery1: Display all details from both tables where movie names are the same
#    SNo.                                         Movie Name  Duration (min)  \
# 0     1                Spider-Man: Across the Spider-Verse             140
# 1     2                                    The Dark Knight             152
# 2     3      The Lord of the Rings: The Return of the King             201
# 3     4                                          Inception             148
# 4     5  The Lord of the Rings: The Fellowship of the Ring             178
# 5     6              The Lord of the Rings: The Two Towers             179
# 6     7                                         The Matrix             136
# 7     8     Star Wars: Episode V - The Empire Strikes Back             124
# 8     9                                    Soorarai Pottru             153
# 9    10                 Star Wars: Episode IV - A New Hope             121
#
# ...

# %%
# 2) Display all movie names, Director, ratings, and gross collection where the genre is action
df_3 = pd.merge(df_1, df_2, on='Movie Name', how='inner')
query2 = df_3[(df_3['Genre1'] == 'Action') | (df_3['Genre2'] == 'Action') | (df_3['Genre3'] == 'Action')]
query2 = query2[['Movie Name', 'Director 1', 'Director 2', 'Director 3', 'Director 4', 'Director 5', \
                 'Director 6', 'Ratings', 'Gross (USD millions)']]
print("Subquery2: Display all movie names, Director, ratings, and gross collection where the genre is action")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(query2) # Determine the number of rows
max_rows = 20 # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    display(query2.head(10))

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    display(query2.tail(10))
else:
    # Print all rows
    display(query2)
# Out:
# Subquery2: Display all movie names, Director, ratings, and gross collection where the genre is action
#                                            Movie Name         Director 1  \
# 1                                     The Dark Knight  Christopher Nolan
# 2       The Lord of the Rings: The Return of the King      Peter Jackson
# 3                                           Inception  Christopher Nolan
# 4   The Lord of the Rings: The Fellowship of the Ring      Peter Jackson
# 5               The Lord of the Rings: The Two Towers      Peter Jackson
# 6                                          The Matrix     Lana Wachowski
# 7      Star Wars: Episode V - The Empire Strikes Back     Irvin Kershner
# 8                                     Soorarai Pottru      Sudha Kongara
# 9                  Star Wars: Episode IV - A New Hope       George Lucas
# 10                         Terminator 2: Judgment Day      James Cameron
#
# ...

# %%
# 3) Display all details from both tables with the highest gross collection.
df_3 = pd.merge(df_1, df_2, on='Movie Name', how='inner')
query3 = df_3.sort_values('Gross (USD millions)', ascending=False).head(1)
print("Subquery3: Display all details from both tables with the highest gross collection")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(query3) # Determine the number of rows
max_rows = 20 # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    display(query3.head(10))

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    display(query3.tail(10))
else:
    # Print all rows
    display(query3)
# Out:
# Subquery3: Display all details from both tables with the highest gross collection
#      SNo.                                  Movie Name  Duration (min)  Year  \
# 136   137  Star Wars: Episode VII - The Force Awakens             138  2015
#
#      Ratings  Metascore   Director 1 Director 2 Director 3 Director 4  \
# 136      7.8       80.0  J.J. Abrams        NaN        NaN        NaN
#
#     Director 5 Director 6   Votes Certification  Gross (USD millions)  \
# 136        NaN        NaN  947641         PG-13                936.66
#
#            Star 1       Star 2       Star 3            Star 4  Genre1  \
# 136  Daisy Ridley  John Boyega  Oscar Isaac  Domhnall Gleeson  Action
#
#          Genre2   Genre3  Popularity
# 136   Adventure   Sci-Fi       455.0

# %%
# 4) Display all details from both tables with the highest ratings.
df_3 = pd.merge(df_1, df_2, on='Movie Name', how='inner')
query4 = df_3.sort_values('Ratings', ascending=False).head(2)
print("Subquery4: Display all details from both tables with the highest ratings")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(query4) # Determine the number of rows
max_rows = 20 # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    display(query4.head(10))

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    display(query4.tail(10))
else:
    # Print all rows
    display(query4)
# Out:
# Subquery4: Display all details from both tables with the highest ratings
#    SNo.                           Movie Name  Duration (min)  Year  Ratings  \
# 0     1  Spider-Man: Across the Spider-Verse             140  2023      9.1
# 1     2                      The Dark Knight             152  2008      9.0
#
#    Metascore          Director 1   Director 2          Director 3 Director 4  \
# 0       86.0  Joaquim Dos Santos  Kemp Powers  Justin K. Thompson        NaN
# 1       84.0   Christopher Nolan          NaN                 NaN        NaN
#
#   Director 5 Director 6    Votes Certification  Gross (USD millions)  \
# 0        NaN        NaN    38365            PG                   NaN
# 1        NaN        NaN  2719626         PG-13                534.86
#
#            Star 1            Star 2         Star 3             Star 4  \
# 0   Shameik Moore  Hailee Steinfeld    Oscar Isaac  Luna Lauren Velez
# 1  Christian Bale      Heath Ledger  Aaron Eckhart      Michael Caine
#
# ...

# %%
# 5) Display all details from both tables with the lowest gross collection and lowest ratings.
df_3 = pd.merge(df_1, df_2, on='Movie Name', how='inner')
query5 = df_3.sort_values(['Gross (USD millions)', 'Ratings'], ascending=True).head(1)
print("Subquery5: Display all details from both tables with the lowest gross collection and lowest ratings")

# I am trying to print max 20 rows for display purpose. Displaying first 10 and last 10 rows for display purpose.

num_rows = len(query5) # Determine the number of rows
max_rows = 20 # Determine the maximum number of rows to print

# Print the results
if num_rows > max_rows:
    # Print first 10 rows
    display(query5.head(10))

    print("-"*100)
    print("-"*100)

    # Print last 10 rows
    display(query5.tail(10))
else:
    # Print all rows
    display(query5)
# Out:
# Subquery5: Display all details from both tables with the lowest gross collection and lowest ratings
#       SNo. Movie Name  Duration (min)  Year  Ratings  Metascore  Director 1  \
# 1482  1483  Wild Card              92  2015      5.6       40.0  Simon West
#
#      Director 2 Director 3 Director 4 Director 5 Director 6  Votes  \
# 1482        NaN        NaN        NaN        NaN        NaN  57783
#
#      Certification  Gross (USD millions)         Star 1            Star 2  \
# 1482             R                   0.0  Jason Statham  Michael Angarano
#
#               Star 3            Star 4  Genre1  Genre2  Genre3  Popularity
# 1482  Dominik Garcia  Milo Ventimiglia  Action   Crime   Drama      3208.0
